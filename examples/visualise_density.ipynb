# %%
import os
import fortecubeview

# %%
SYSNAME = "water-dimer-1.00"

# %%
# !pwd

# %%
fname = os.path.join("water-dimer-cubes", "delta_dm.cube")
# ISOLVL = 0.0002

fortecubeview.plot(
    cubes=[fname],
    # levels=[1.518137E-04, -1.093235E-04], # 85%
    levels=[2.970945e-04, -2.317530e-04],  # 75%
    colors=["orange", "blue"],
    opacity=0.75,
    width=800,
    height=500,
)
