# %%
import fortecubeview

# !pwd # we should be in `examples`

fortecubeview.plot(
    "water-dimer-cubes",
    levels=[1e-4, -1e-4],
    colors=["orange", "blue"],
    opacity=0.75,
    width=800,
    height=500,
)
